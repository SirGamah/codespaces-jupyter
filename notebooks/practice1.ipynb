# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv('/workspaces/codespaces-jupyter/data/atlantis.csv')

data.head()
# Out:
#    year  population
# 0  2000       12400
# 1  2001       12800
# 2  2002       13800
# 3  2003       13600
# 4  2004       14200

# %%
data.shape
# Out:
# (22, 2)

# %%
data.plot(kind = 'barh', x = 'year', y = 'population')
# Out:
# <AxesSubplot: ylabel='year'>
